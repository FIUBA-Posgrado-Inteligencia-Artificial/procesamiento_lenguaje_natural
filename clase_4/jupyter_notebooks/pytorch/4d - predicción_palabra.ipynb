# %% [markdown]
# <img src="https://github.com/hernancontigiani/ceia_memorias_especializacion/raw/master/Figures/logoFIUBA.jpg" width="500" align="center">
#
#
# # Procesamiento de lenguaje natural
# ## Predicción de próxima palabra

# %% [markdown]
# ### Objetivo
# El objetivo es utilizar documentos / corpus para crear embeddings de palabras basado en ese contexto utilizando la layer Embedding de Keras. Se utilizará esos embeddings junto con layers LSTM para predeccir la próxima posible palabra.

# %%
import random
import io
import pickle

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import torch
import torch.nn.functional as F
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader

# %%
# torchsummar actualmente tiene un problema con las LSTM, por eso
# se utiliza torchinfo, un fork del proyecto original con el bug solucionado
# !pip3 install torchinfo
from torchinfo import summary
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchinfo
#   Downloading torchinfo-1.7.0-py3-none-any.whl (22 kB)
# Installing collected packages: torchinfo
# Successfully installed torchinfo-1.7.0

# %%
import os
import platform

if os.access('torch_helpers.py', os.F_OK) is False:
    if platform.system() == 'Windows':
        # !curl !wget https://raw.githubusercontent.com/FIUBA-Posgrado-Inteligencia-Artificial/procesamiento_lenguaje_natural/main/scripts/torch_helpers.py > torch_helpers.py
    else:
        # !wget torch_helpers.py https://raw.githubusercontent.com/FIUBA-Posgrado-Inteligencia-Artificial/procesamiento_lenguaje_natural/main/scripts/torch_helpers.py
# Out:
# --2022-06-13 20:07:28--  http://torch_helpers.py/
# Resolving torch_helpers.py (torch_helpers.py)... failed: Name or service not known.
# wget: unable to resolve host address ‘torch_helpers.py’
# --2022-06-13 20:07:28--  https://raw.githubusercontent.com/FIUBA-Posgrado-Inteligencia-Artificial/procesamiento_lenguaje_natural/main/scripts/torch_helpers.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 23883 (23K) [text/plain]
# Saving to: ‘torch_helpers.py’
#
# torch_helpers.py    100%[===================>]  23.32K  --.-KB/s    in 0.002s
#
# 2022-06-13 20:07:28 (9.54 MB/s) - ‘torch_helpers.py’ saved [23883/23883]
#
# FINISHED --2022-06-13 20:07:28--
# Total wall clock time: 0.2s
# Downloaded: 1 files, 23K in 0.002s (9.54 MB/s)

# %%
from torch_helpers import categorical_acc

def train(model, train_loader, valid_loader, optimizer, criterion, epochs=100):
    # Defino listas para realizar graficas de los resultados
    train_loss = []
    train_accuracy = []
    valid_loss = []
    valid_accuracy = []

    # Defino mi loop de entrenamiento

    for epoch in range(epochs):

        epoch_train_loss = 0.0
        epoch_train_accuracy = 0.0

        for train_data, train_target in train_loader:
            # Seteo los gradientes en cero ya que, por defecto, PyTorch
            # los va acumulando
            optimizer.zero_grad()

            output = model(train_data)

            # Computo el error de la salida comparando contra las etiquetas
            loss = criterion(output, train_target)

            # Almaceno el error del batch para luego tener el error promedio de la epoca
            epoch_train_loss += loss.item()

            # Computo el nuevo set de gradientes a lo largo de toda la red
            loss.backward()

            # Realizo el paso de optimizacion actualizando los parametros de toda la red
            optimizer.step()

            # Calculo el accuracy del batch
            accuracy = categorical_acc(output, train_target)
            # Almaceno el accuracy del batch para luego tener el accuracy promedio de la epoca
            epoch_train_accuracy += accuracy.item()

        # Calculo la media de error para la epoca de entrenamiento.
        # La longitud de train_loader es igual a la cantidad de batches dentro de una epoca.
        epoch_train_loss = epoch_train_loss / len(train_loader)
        train_loss.append(epoch_train_loss)
        epoch_train_accuracy = epoch_train_accuracy / len(train_loader)        
        train_accuracy.append(epoch_train_accuracy)

        # Realizo el paso de validación computando error y accuracy, y
        # almacenando los valores para imprimirlos y graficarlos
        valid_data, valid_target = iter(valid_loader).next()
        output = model(valid_data)
        
        epoch_valid_loss = criterion(output, valid_target).item()
        valid_loss.append(epoch_valid_loss)

        # Calculo el accuracy de la epoch
        epoch_valid_accuracy = categorical_acc(output, valid_target).item()
        valid_accuracy.append(epoch_valid_accuracy)

        print(f"Epoch: {epoch+1}/{epochs} - Train loss {epoch_train_loss:.3f} - Train accuracy {epoch_train_accuracy:.3f} - Valid Loss {epoch_valid_loss:.3f} - Valid accuracy {epoch_valid_accuracy:.3f}")

    history = {
        "loss": train_loss,
        "accuracy": train_accuracy,
        "val_loss": valid_loss,
        "val_accuracy": valid_accuracy,
    }
    return history

# %% [markdown]
# ### Datos
# Utilizaremos como dataset canciones de bandas de habla inglés.

# %%
# Descargar la carpeta de dataset
import os
import platform
if os.access('./songs_dataset', os.F_OK) is False:
    if os.access('songs_dataset.zip', os.F_OK) is False:
        if platform.system() == 'Windows':
            # !curl https://raw.githubusercontent.com/FIUBA-Posgrado-Inteligencia-Artificial/procesamiento_lenguaje_natural/main/datasets/songs_dataset.zip -o songs_dataset.zip
        else:
            # !wget songs_dataset.zip https://github.com/FIUBA-Posgrado-Inteligencia-Artificial/procesamiento_lenguaje_natural/raw/main/datasets/songs_dataset.zip
    # !unzip -q songs_dataset.zip   
else:
    print("El dataset ya se encuentra descargado")
# Out:
# --2022-06-13 20:07:28--  http://songs_dataset.zip/
# Resolving songs_dataset.zip (songs_dataset.zip)... failed: Name or service not known.
# wget: unable to resolve host address ‘songs_dataset.zip’
# --2022-06-13 20:07:28--  https://github.com/FIUBA-Posgrado-Inteligencia-Artificial/procesamiento_lenguaje_natural/raw/main/datasets/songs_dataset.zip
# Resolving github.com (github.com)... 140.82.112.4
# Connecting to github.com (github.com)|140.82.112.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/FIUBA-Posgrado-Inteligencia-Artificial/procesamiento_lenguaje_natural/main/datasets/songs_dataset.zip [following]
# --2022-06-13 20:07:29--  https://raw.githubusercontent.com/FIUBA-Posgrado-Inteligencia-Artificial/procesamiento_lenguaje_natural/main/datasets/songs_dataset.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2075036 (2.0M) [application/zip]
# Saving to: ‘songs_dataset.zip’
#
# songs_dataset.zip   100%[===================>]   1.98M  --.-KB/s    in 0.06s
#
# 2022-06-13 20:07:29 (33.3 MB/s) - ‘songs_dataset.zip’ saved [2075036/2075036]
#
# FINISHED --2022-06-13 20:07:29--
# Total wall clock time: 0.7s
# Downloaded: 1 files, 2.0M in 0.06s (33.3 MB/s)

# %%
# Posibles bandas
os.listdir("./songs_dataset/")
# Out:
# ['adele.txt',
#  'rihanna.txt',
#  'disney.txt',
#  'kanye.txt',
#  'michael-jackson.txt',
#  'nirvana.txt',
#  'dr-seuss.txt',
#  'bob-marley.txt',
#  'dickinson.txt',
#  'joni-mitchell.txt',
#  'drake.txt',
#  'nicki-minaj.txt',
#  'jimi-hendrix.txt',
#  'paul-simon.txt',
#  'dolly-parton.txt',
#  'lil-wayne.txt',
#  'bruce-springsteen.txt',
#  'amy-winehouse.txt',
#  'r-kelly.txt',
#  'janisjoplin.txt',
#  'beatles.txt',
#  'lady-gaga.txt',
#  'kanye-west.txt',
#  'bieber.txt',
#  'bjork.txt',
#  'Lil_Wayne.txt',
#  'al-green.txt',
#  'cake.txt',
#  'nursery_rhymes.txt',
#  'lorde.txt',
#  'britney-spears.txt',
#  'nickelback.txt',
#  'bob-dylan.txt',
#  'leonard-cohen.txt',
#  'prince.txt',
#  'Kanye_West.txt',
#  'notorious_big.txt',
#  'alicia-keys.txt',
#  'notorious-big.txt',
#  'johnny-cash.txt',
#  'blink-182.txt',
#  'missy-elliott.txt',
#  'patti-smith.txt',
#  'bruno-mars.txt',
#  'lin-manuel-miranda.txt',
#  'dj-khaled.txt',
#  'ludacris.txt',
#  'eminem.txt',
#  'radiohead.txt']

# %%
# Armar el dataset utilizando salto de línea para separar las oraciones/docs
df = pd.read_csv('songs_dataset/beatles.txt', sep='/n', header=None)
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
#                                                    0
# 0      Yesterday, all my troubles seemed so far away
# 1        Now it looks as though they're here to stay
# 2  Oh, I believe in yesterday Suddenly, I'm not h...
# 3                  There's a shadow hanging over me.
# 4  Oh, yesterday came suddenly Why she had to go ...

# %%
print("Cantidad de documentos:", df.shape[0])
# Out:
# Cantidad de documentos: 1846

# %% [markdown]
# ### 1 - Ejemplo de Preprocesamiento
# - Hay que transformar las oraciones en tokens.
# - Dichas oraciones hay que ajustarlas al tamaño fijo de nuestra sentencia de entrada al modelo.
# - Hay que separar las palabras objetivos (target) que el modelo debe predecir en cada sentencia armada.

# %%
from torch_helpers import Tokenizer # tool de keras equivalente a ltokenizer de nltk
from torch_helpers import text_to_word_sequence # tool de keras equivalente a word_teokenize de nltk
from torch_helpers import pad_sequences # tool de keras qye se utilizará para padding

# largo de la secuencia, incluye seq input + word output
train_len = 4

# %%
# Ejemplo de como transformar una oración a tokens usando keras
text = df.loc[0,0]
text
# Out:
# 'Yesterday, all my troubles seemed so far away'

# %%
tokens = text_to_word_sequence(text) # entran oraciones -> salen vectores de N posiciones (tokens)
tokens
# Out:
# ['yesterday', 'all', 'my', 'troubles', 'seemed', 'so', 'far', 'away']

# %% [markdown]
# 1.1 - Transformar las oraciones en secuencias (tokens) de palabras

# %%
# Recorrer todas las filas y transformar las oraciones
# en secuencias de palabras
sentence_tokens = []
for _, row in df[:None].iterrows():
    sentence_tokens.append(text_to_word_sequence(row[0]))

# %%
# Demos un vistazo
sentence_tokens[:2]
# Out:
# [['yesterday', 'all', 'my', 'troubles', 'seemed', 'so', 'far', 'away'],
#  ['now', 'it', 'looks', 'as', 'though', "they're", 'here', 'to', 'stay']]

# %%
# Código para hacer el desfazaje de las palabras
# según el train_len
text_sequences = []

for i in range(train_len, len(tokens)):
  seq = tokens[i-train_len:i]
  text_sequences.append(seq)

# %%
# Demos un vistazo a nuestros vectores para entrenar el modelo
# seq_input + output
text_sequences
# Out:
# [['yesterday', 'all', 'my', 'troubles'],
#  ['all', 'my', 'troubles', 'seemed'],
#  ['my', 'troubles', 'seemed', 'so'],
#  ['troubles', 'seemed', 'so', 'far']]

# %% [markdown]
# 1.2 - Crear los vectores de palabras (word2vec)
#
# Ahora necesitamos pasarlos a números para que lo entienda la red y separar input de output.
# - El Input seran integers (word2vec)
# - Mientras que el output será one hot encodeado (labels) del tamaño del vocabulario

# %%
tok = Tokenizer()

# El tokeinzer "aprende" las palabras que se usaran
# Se construye (fit) una vez por proyecto, se aplica N veces (tal cual un encoder)
tok.fit_on_texts(text_sequences)

# Convertimos las palabras a números
# entran palabras -> salen números
sequences = tok.texts_to_sequences(text_sequences)

# %%
# Ahora sequences tiene los números "ID", largo 4
sequences
# Out:
# [[6, 4, 2, 1], [4, 2, 1, 3], [2, 1, 3, 5], [1, 3, 5, 7]]

# %%
# Cantidad de casos (doc) de entrada
print(tok.document_count)
# Out:
# 4

# %%
# Cantidad de palabras distintas
print(len(tok.word_counts))
# Out:
# 7

# %%
# El índice para cada palabra
# El sistema las ordena de las más populares a las menos populares
print(tok.word_index)
# Out:
# {'troubles': 1, 'my': 2, 'seemed': 3, 'all': 4, 'so': 5, 'yesterday': 6, 'far': 7}

# %%
# Cantidad de veces quea aparece cada palabra en cada "documento"
# (1 documento = 1 caso de entrada)
print(tok.word_docs)
# Out:
# defaultdict(<class 'int'>, {'troubles': 4, 'yesterday': 1, 'my': 3, 'all': 2, 'seemed': 3, 'so': 2, 'far': 1})

# %% [markdown]
# ### 2 - Preprocesamiento completo
# Debemos realizar los mismos pasos que en el ejemplo anterior, pero antes de eso debemos transformar ese dataset de filas de oraciones en un texto completo continuo para poder extraer el vocabulario.

# %%
# Vistazo a las primeras filas
df.loc[:15,0]
# Out:
# 0         Yesterday, all my troubles seemed so far away
# 1           Now it looks as though they're here to stay
# 2     Oh, I believe in yesterday Suddenly, I'm not h...
# 3                     There's a shadow hanging over me.
# 4     Oh, yesterday came suddenly Why she had to go ...
# 5     I said something wrong, now I long for yesterd...
# 6                       Now I need a place to hide away
# 7     Oh, I believe in yesterday Why she had to go I...
# 8     I said something wrong, now I long for yesterd...
# 9                       Now I need a place to hide away
# 10                           Oh, I believe in yesterday
# 11    Mm mm mm mm mm mm mm When I find myself in tim...
# 12                  Speaking words of wisdom, let it be
# 13    And in my hour of darkness she is standing rig...
# 14                  Speaking words of wisdom, let it be
# 15           Let it be, let it be, let it be, let it be
# Name: 0, dtype: object

# %%
# Concatenamos todos los rows en un solo valor
corpus = df.apply(lambda row: ' '.join(row.values.astype(str)), axis=0)[0]
corpus
# Out:
# 'Yesterday, all my troubles seemed so far away Now it looks as though they\'re here to stay Oh, I believe in yesterday Suddenly, I\'m not half the man I used to be There\'s a shadow hanging over me. Oh, yesterday came suddenly Why she had to go I don\'t know she wouldn\'t say I said something wrong, now I long for yesterday Yesterday, love was such an easy game to play Now I need a place to hide away Oh, I believe in yesterday Why she had to go I don\'t know she wouldn\'t say I said something wrong, now I long for yesterday Yesterday, love was such an easy game to play Now I need a place to hide away Oh, I believe in yesterday Mm mm mm mm mm mm mm When I find myself in times of trouble, Mother Mary comes to me Speaking words of wisdom, let it be And in my hour of darkness she is standing right in front of me Speaking words of wisdom, let it be Let it be, let it be, let it be, let it be Whisper words of wisdom, let it be And when the broken hearted people living in the world agree There will be an answer, let it be For though they may be parted, there is still a chance that they will see There will be an answer, let it be Let it be, let it be, let it be, let it be There will be an answer, let it be Let it be, let it be, let it be, let it be Whisper words of wisdom, let it be Let it be, let it be, let it be, let it be Whisper words of wisdom, let it be And when the night is cloudy there is still a light that shines on me Shine until tomorrow, let it be I wake up to the sound of music, Mother Mary comes to me Speaking words of wisdom, let it be Let it be, let it be, let it be, yeah, let it be There will be an answer, let it be Let it be, let it be, let it be, yeah, let it be Whisper words of wisdom, let it be Words are flowing out like Endless rain into a paper cup They slither wildly as they slip away across the universe. Pools of sorrow waves of joy Are drifting through my opened mind Possessing and caressing me. Jai Guru Deva. Om Nothing\'s gonna change my world Nothing\'s gonna change my world Nothing\'s gonna change my world Nothing\'s gonna change my world Images of broken light, which Dance before me like a million eyes, They call me on and on across the universe. Thoughts meander like a Restless wind inside a letter box They tumble blindly as they make their way across the universe. Jai Guru Deva. Om Nothing\'s gonna change my world Nothing\'s gonna change my world Nothing\'s gonna change my world Nothing\'s gonna change my world Sounds of laughter, shades of life Are ringing through my opened ears Inciting and inviting me. Limitless undying love, which Shines around me like a million suns, It calls me on and on across the universe Jai Guru Deva, om. Nothing\'s gonna change my world Nothing\'s gonna change my world Nothing\'s gonna change my world Nothing\'s gonna change my world Jai Guru Deva Jai Guru Deva Jai Guru Deva Jai Guru Deva Jai Guru Deva Hey Jude, don\'t make it bad Take a sad song and make it better Remember to let her into your heart Then you can start to make it better Hey Jude, don\'t be afraid You were made to go out and get her The minute you let her under your skin Then you begin to make it better And anytime you feel the pain, hey Jude, refrain Don\'t carry the world upon your shoulders For well you know that it\'s a fool who plays it cool By making his world a little colder Nah nah nah nah nah nah nah nah nah Hey Jude, don\'t let me down You have found her, now go and get her Remember to let her into your heart Then you can start to make it better So let it out and let it in, hey Jude, begin You\'re waiting for someone to perform with And don\'t you know that it\'s just you, hey Jude, you\'ll do The movement you need is on your shoulder Nah nah nah nah nah nah nah nah nah yeah Hey Jude, don\'t make it bad Take a sad song and make it better Remember to let her under your skin Then you\'ll begin to make it Better better better better better better, oh Nah nah nah nah nah nah, nah nah nah, hey Jude Nah na ...

# %%
# Transformar el corpus a tokens
tokens=text_to_word_sequence(corpus)
# Vistazo general de los primeros tokens
tokens[:20]
# Out:
# ['yesterday',
#  'all',
#  'my',
#  'troubles',
#  'seemed',
#  'so',
#  'far',
#  'away',
#  'now',
#  'it',
#  'looks',
#  'as',
#  'though',
#  "they're",
#  'here',
#  'to',
#  'stay',
#  'oh',
#  'i',
#  'believe']

# %%
print("Cantidad de tokens en el corpus:", len(tokens))
# Out:
# Cantidad de tokens en el corpus: 14387

# %%
# Código para hacer el desfazaje de las palabras
# según el train_len
text_sequences = []
for i in range(train_len, len(tokens)):
  seq = tokens[i-train_len:i]
  text_sequences.append(seq)

# %%
# Demos un vistazo a nuestros vectores para entrenar el modelo
text_sequences[:20]
# Out:
# [['yesterday', 'all', 'my', 'troubles'],
#  ['all', 'my', 'troubles', 'seemed'],
#  ['my', 'troubles', 'seemed', 'so'],
#  ['troubles', 'seemed', 'so', 'far'],
#  ['seemed', 'so', 'far', 'away'],
#  ['so', 'far', 'away', 'now'],
#  ['far', 'away', 'now', 'it'],
#  ['away', 'now', 'it', 'looks'],
#  ['now', 'it', 'looks', 'as'],
#  ['it', 'looks', 'as', 'though'],
#  ['looks', 'as', 'though', "they're"],
#  ['as', 'though', "they're", 'here'],
#  ['though', "they're", 'here', 'to'],
#  ["they're", 'here', 'to', 'stay'],
#  ['here', 'to', 'stay', 'oh'],
#  ['to', 'stay', 'oh', 'i'],
#  ['stay', 'oh', 'i', 'believe'],
#  ['oh', 'i', 'believe', 'in'],
#  ['i', 'believe', 'in', 'yesterday'],
#  ['believe', 'in', 'yesterday', 'suddenly']]

# %%
# Proceso de tokenizacion
tok = Tokenizer() 
tok.fit_on_texts(text_sequences) 

# Convertimos las palabras a números
# entran palabras -> salen números
sequences = tok.texts_to_sequences(text_sequences)

# Damos un vistazo
sequences[:20]
# Out:
# [[216, 10, 12, 907],
#  [10, 12, 907, 908],
#  [12, 907, 908, 42],
#  [907, 908, 42, 909],
#  [908, 42, 909, 121],
#  [42, 909, 121, 22],
#  [909, 121, 22, 13],
#  [121, 22, 13, 638],
#  [22, 13, 638, 91],
#  [13, 638, 91, 217],
#  [638, 91, 217, 349],
#  [91, 217, 349, 79],
#  [217, 349, 79, 4],
#  [349, 79, 4, 314],
#  [79, 4, 314, 23],
#  [4, 314, 23, 2],
#  [314, 23, 2, 160],
#  [23, 2, 160, 9],
#  [2, 160, 9, 216],
#  [160, 9, 216, 520]]

# %%
print("Cantidad de rows del dataset:", len(sequences))
# Out:
# Cantidad de rows del dataset: 14383

# %% [markdown]
# ### 3 - Input y target

# %%
# Con numpy es muy fácil realizar el slicing de vectores
ex = np.array([[1,2,3,4],[5,6,7,8]])
ex
# Out:
# array([[1, 2, 3, 4],
#        [5, 6, 7, 8]])

# %%
# Con numpy es muy fácil realizar el slicing de vectores
print("Dimension:", ex.shape)
print("Todos los elementos:", ex)
print("Todos los elementos menos el último:", ex[:, :-1])
# Out:
# Dimension: (2, 4)
# Todos los elementos: [[1 2 3 4]
#  [5 6 7 8]]
# Todos los elementos menos el último: [[1 2 3]
#  [5 6 7]]

# %%
input = ex[:,:-1] # todos los rows, menos la ultima col
target = ex[:, -1] # última col de cada row

print("Input:", input)
print("Target:", target)
# Out:
# Input: [[1 2 3]
#  [5 6 7]]
# Target: [4 8]

# %%
arr_sequences = np.array(sequences)
x_data = arr_sequences[:,:-1]
y_data_int = arr_sequences[:,-1] # aún falta el oneHotEncoder

print(x_data.shape)
print(y_data_int.shape)
# Out:
# (14383, 3)
# (14383,)

# %%
# Palabras del vocabulario
tok.index_word
# Out:
# {1: 'you',
#  2: 'i',
#  3: 'the',
#  4: 'to',
#  5: 'and',
#  6: 'love',
#  7: 'a',
#  8: 'me',
#  9: 'in',
#  10: 'all',
#  11: 'nah',
#  12: 'my',
#  13: 'it',
#  14: 'know',
#  15: 'be',
#  16: 'that',
#  17: 'of',
#  18: 'on',
#  19: 'she',
#  20: 'is',
#  21: 'say',
#  22: 'now',
#  23: 'oh',
#  24: 'yeah',
#  25: 'your',
#  26: 'get',
#  27: "don't",
#  28: 'back',
#  29: 'let',
#  30: 'with',
#  31: 'her',
#  32: 'can',
#  33: "it's",
#  34: 'do',
#  35: "i'm",
#  36: 'when',
#  37: 'come',
#  38: 'will',
#  39: 'he',
#  40: 'but',
#  41: 'for',
#  42: 'so',
#  43: 'need',
#  44: 'there',
#  45: 'like',
#  46: 'together',
#  47: 'no',
#  48: "i'll",
#  49: 'see',
#  50: 'was',
#  51: 'never',
#  52: 'we',
#  53: 'down',
#  54: 'way',
#  55: 'if',
#  56: 'want',
#  57: 'out',
#  58: 'hey',
#  59: 'one',
#  60: 'got',
#  61: 'go',
#  62: 'well',
#  63: "can't",
#  64: 'girl',
#  65: 'good',
#  66: 'his',
#  67: 'sun',
#  68: 'they',
#  69: 'home',
#  70: 'hello',
#  71: 'day',
#  72: 'are',
#  73: 'ah',
#  74: 'right',
#  75: 'little',
#  76: 'at',
#  77: 'from',
#  78: 'man',
#  79: 'here',
#  80: 'help',
#  81: 'gonna',
#  82: 'have',
#  83: 'not',
#  84: 'world',
#  85: 'going',
#  86: 'what',
#  87: 'still',
#  88: 'how',
#  89: 'too',
#  90: 'please',
#  91: 'as',
#  92: "you're",
#  93: 'just',
#  94: 'time',
#  95: 'make',
#  96: 'long',
#  97: 'yes',
#  98: 'yellow',
#  99: 'life',
#  100: 'why',
#  101: 'think',
#  102: 'only',
#  103: 'been',
#  104: 'once',
#  105: 'tell',
#  106: 'sky',
#  107: 'people',
#  108: 'eyes',
#  109: 'where',
#  110: "she's",
#  111: 'up',
#  112: 'jude',
#  113: 'take',
#  114: 'submarine',
#  115: 'sing',
#  116: 'give',
#  117: 'nowhere',
#  118: 'hold',
#  119: 'look',
#  120: 'goodbye',
#  121: 'away',
#  122: 'friends',
#  123: 'darling',
#  124: 'lonely',
#  125: 'boy',
#  126: 'nothing',
#  127: 'always',
#  128: 'hand',
#  129: "we're",
#  130: 'am',
#  131: 'goo',
#  132: 'should',
#  133: 'comes',
#  134: 'night',
#  135: 'feel',
#  136: 'some',
#  137: 'could',
#  138: 'had',
#  139: 'better',
#  140: 'them',
#  141: 'would',
#  142: 'head',
#  143: "i've",
#  144: 'more',
#  145: 'four',
#  146: 'buy',
#  147: 'mind',
#  148: 'carry',
#  149: 'this',
#  150: 'la',
#  151: 'everything',
#  152: 'two',
#  153: 'change',
#  154: 'by',
#  155: 'weight',
#  156: 'us',
#  157: 'our',
#  158: 'lucy',
#  159: 'sunshine',
#  160: 'believe',
#  161: 'an',
#  162: 'words',
#  163: 'before',
#  164: "you'll",
#  165: 'these',
#  166: 'pretty',
#  167: 'birthday',
#  168: "i'd",
#  169: 'three',
#  170: 'every',
#  171: 'diamonds',
#  172: 'true',
#  173: "there's",
#  174: 'said',
#  175: 'mm',
#  176: 'were',
#  177: 'forever',
#  178: 'dear',
#  179: 'mine',
#  180: 'nobody',
#  181: 'round',
#  182: 'leave',
#  183: 'money',
#  184: 'told',
#  185: 'work',
#  186: 'bom',
#  187: 'something',
#  188: 'hide',
#  189: 'standing',
#  190: 'then',
#  191: 'who',
#  192: 'waiting',
#  193: 'about',
#  194: "'cause",
#  195: 'children',
#  196: 'saw',
#  197: "didn't",
#  198: 'try',
#  199: 'loves',
#  200: "nothing's",
#  201: 'gone',
#  202: 'things',
#  203: 'stop',
#  204: 'sleep',
#  205: 'cry',
#  206: 'hard',
#  207: 'di',
#  208: "he's",
#  209: 'days',
#  210: 'alone',
#  211: 'because',
#  212: 'falling',
#  213: 'again',
#  214: 'prudence',
#  215: 'bang',
#  216: 'yesterday',
#  217: 'though',
#  218: 'came',
#  219: 'around',
#  220: 'mean',
#  221: 'has',
#  222: 'till',
#  223: 'juba',
#  224: 'shake',
#  225: 'loving',
#  226: 'eight',
#  227: 'five',
#  228: 'play',
#  229: 'place',
#  230: 'find',
#  231: 'may',
#  232: 'someone',
#  233: 'dead',
#  234: 'years',
#  235: 'send',
#  236: 'strawberry',
#  237: 'fields',
#  238: 'or',
#  239: 'band',
#  240: 'door',
#  241: 'happy',
#  242: 'garden',
#  243: 'anybody',
#  244: 'today',
#  245: "won't",
#  246: 'live',
#  247: 'blue',
#  248: 'while',
#  249: 'hela',
#  250: 'heaven',
#  251: 'week',
#  252: 'six',
#  253: 'seven',
#  254: 'rocky',
#  255: 'such',
#  256: 'easy',
#  257: 'answer',
#  258: 'into',
#  259: 'dance',
#  260: 'heart',
#  261: 'lullaby',
#  262: 'high',
#  263: 'face',
#  264: 'him',
#  265: 'does',
#  266: 'ask',
#  267: 'somebody',
#  268: 'any',
#  269: 'feeling',
#  270: 'knows',
#  271: 'talk',
#  272: "you've",
#  273: 'another',
#  274: 'belonged',
#  275: 'glad',
#  276: 'heba',
#  277: 'helloa',
#  278: 'baby',
#  279: 'twist',
#  280: 'kind',
#  281: 'care',
#  282: 'jai',
#  283: 'guru',
#  284: 'deva',
#  285: 'bad',
#  286: 'fool',
#  287: 'found',
#  288: 'loved',
#  289: 'fly',
#  290: 'seems',
#  291: 'fill',
#  292: 'done',
#  293: "isn't",
#  294: 'real',
#  295: 'much',
#  296: 'molly',
#  297: 'ever',
#  298: 'many',
#  299: 'understand',
#  300: 'sea',
#  301: 'beneath',
#  302: "g'",
#  303: 'joob',
#  304: 'penny',
#  305: 'lane',
#  306: 'keeps',
#  307: 'whoa',
#  308: 'sgt',
#  309: 'bompa',
#  310: 'ussr',
#  311: 'silver',
#  312: 'hoo',
#  313: 'taxman',
#  314: 'stay',
#  315: 'wisdom',
#  316: 'rain',
#  317: 'their',
#  318: 'remember',
#  319: 'made',
#  320: 'new',
#  321: 'went',
#  322: 'blackbird',
#  323: 'must',
#  324: 'desmond',
#  325: 'sweet',
#  326: 'last',
#  327: 'really',
#  328: 'smile',
#  329: 'show',
#  330: 'hear',
#  331: 'hmm',
#  332: 'crying',
#  333: 'sitting',
#  334: 'tired',
#  335: "that's",
#  336: 'behind',
#  337: 'room',
#  338: 'hope',
#  339: 'alright',
#  340: "pepper's",
#  341: 'lead',
#  342: 'everywhere',
#  343: 'road',
#  344: 'babe',
#  345: "octopus'",
#  346: 'bulldog',
#  347: 'woah',
#  348: 'hammer',
#  349: "they're",
#  350: 'wrong',
#  351: 'living',
#  352: 'through',
#  353: 'ears',
#  354: 'song',
#  355: 'under',
#  356: 'making',
#  357: 'changed',
#  358: 'lose',
#  359: 'singing',
#  360: 'learn',
#  361: 'dark',
#  362: 'homeward',
#  363: 'dream',
#  364: 'hair',
#  365: 'feed',
#  366: 'sixty',
#  367: 'doing',
#  368: "somethin'",
#  369: 'feet',
#  370: 'other',
#  371: 'old',
#  372: 'looking',
#  373: 'hill',
#  374: 'heard',
#  375: 'guitar',
#  376: 'gently',
#  377: 'weeps',
#  378: 'laugh',
#  379: 'fell',
#  380: 'michelle',
#  381: 'tres',
#  382: 'bien',
#  383: 'ensemble',
#  384: 'thought',
#  385: 'girls',
#  386: 'party',
#  387: 'shout',
#  388: 'each',
#  389: 'tight',
#  390: 'friend',
#  391: 'calling',
#  392: 'imagine',
#  393: 'harm',
#  394: 'phone',
#  395: "maxwell's",
#  396: 'o',
#  397: 'over',
#  398: 'times',
#  399: 'broken',
#  400: 'light',
#  401: 'until',
#  402: 'paper',
#  403: 'across',
#  404: 'waves',
#  405: 'wind',
#  406: 'sad',
#  407: 'moment',
#  408: 'free',
#  409: 'since',
#  410: 'smiles',
#  411: 'middle',
#  412: 'break',
#  413: 'dreams',
#  414: "doesn't",
#  415: 'says',
#  416: 'takes',
#  417: 'ob',
#  418: 'knee',
#  419: 'than',
#  420: 'thing',
#  421: 'walrus',
#  422: "ain't",
#  423: 'near',
#  424: 'turn',
#  425: 'seen',
#  426: 'lucky',
#  427: 'sure',
#  428: 'bed',
#  429: 'very',
#  430: 'skies',
#  431: 'sit',
#  432: 'knew',
#  433: 'left',
#  434: 'makes',
#  435: 'yourself',
#  436: 'rock',
#  437: 'spinning',
#  438: 'kiss',
#  439: 'die',
#  440: 'oo',
#  441: 'hearts',
#  442: 'club',
#  443: 'met',
#  444: 'peace',
#  445: 'sees',
#  446: "wouldn't",
#  447: 'speaking',
#  448: 'whisper',
#  449: 'chance',
#  450: 'tomorrow',
#  451: 'music',
#  452: 'universe',
#  453: 'opened',
#  454: 'start',
#  455: 'upon',
#  456: 'places',
#  457: 'lovers',
#  458: 'affection',
#  459: 'often',
#  460: 'arise',
#  461: 'black',
#  462: 'doo',
#  463: 'golden',
#  464: 'tonight',
#  465: 'end',
#  466: 'save',
#  467: 'known',
#  468: 'hung',
#  469: 'tree',
#  470: 'low',
#  471: 'chorus',
#  472: 'goes',
#  473: 'ring',
#  474: 'couple',
#  475: 'after',
#  476: 'older',
#  477: 'wine',
#  478: 'point',
#  479: 'view',
#  480: 'indicate',
#  481: 'first',
#  482: 'younger',
#  483: 'ground',
#  484: 'green',
#  485: 'ahead',
#  486: 'apart',
#  487: 'stand',
#  488: 'run',
#  489: 'eggman',
#  490: 'eggmen',
#  491: 'ho',
#  492: 'sleeping',
#  493: 'read',
#  494: 'news',
#  495: 'ma',
#  496: 'belle',
#  497: 'everyone',
#  498: 'write',
#  499: 'roll',
#  500: 'off',
#  501: 'looked',
#  502: 'working',
#  503: 'hands',
#  504: 'held',
#  505: "day's",
#  506: 'lot',
#  507: 'tells',
#  508: 'wants',
#  509: 'knowing',
#  510: 'someday',
#  511: 'listen',
#  512: 'shade',
#  513: 'anymore',
#  514: 'nearly',
#  515: 'broke',
#  516: 'ha',
#  517: 'plans',
#  518: 'maxwell',
#  519: 'tax',
#  520: 'suddenly',
#  521: 'game',
#  522: 'myself',
#  523: 'shine',
#  524: 'om',
#  525: 'inside',
#  526: 'ringing',
#  527: 'calls',
#  528: 'begin',
#  529: 'pain',
#  530: 'plays',
#  531: 'feels',
#  532: 'slowly',
#  533: 'slumbers',
#  534: 'rise',
#  535: 'equal',
#  536: 'everybody',
#  537: 'getting',
#  538: 'da',
#  539: 'gives',
#  540: 'built',
#  541: 'running',
#  542: 'lend',
#  543: 'evening',
#  544: 'sending',
#  545: 'lights',
#  546: 'sunday',
#  547: 'summer',
#  548: 'rent',
#  549: 'drop',
#  550: 'touch',
#  551: 'guess',
#  552: 'appreciate',
#  553: 'being',
#  554: 'lover',
#  555: 'shows',
#  556: 'grow',
#  557: 'below',
#  558: 'wonderful',
#  559: "we'd",
#  560: 'pictures',
#  561: 'lived',
#  562: 'land',
#  563: 'full',
#  564: 'speed',
#  565: 'mr',
#  566: 'sir',
#  567: 'name',
#  568: 'loud',
#  569: 'walk',
#  570: 'row',
#  571: 'english',
#  572: 'hee',
#  573: 'hah',
#  574: 'father',
#  575: 'notice',
#  576: 'house',
#  577: 'holes',
#  578: 'small',
#  579: 'sont',
#  580: 'les',
#  581: 'mots',
#  582: 'qui',
#  583: 'vont',
#  584: 'hoping',
#  585: 'barber',
#  586: 'banker',
#  587: 'suburban',
#  588: 'meanwhile',
#  589: 'keep',
#  590: 'jojo',
#  591: 'cha',
#  592: 'boat',
#  593: 'junior',
#  594: 'behave',
#  595: 'lost',
#  596: "you'd",
#  597: 'ooh',
#  598: 'morning',
#  599: 'honey',
#  600: 'fine',
#  601: 'woo',
#  602: 'hurt',
#  603: 'belong',
#  604: 'writing',
#  605: 'died',
#  606: 'fall',
#  607: 'missing',
#  608: 'dog',
#  609: 'earth',
#  610: 'ok',
#  611: 'holding',
#  612: 'diamond',
#  613: 'anything',
#  614: 'ago',
#  615: "we've",
#  616: 'wonder',
#  617: 'winding',
#  618: 'cried',
#  619: 'tried',
#  620: 'young',
#  621: 'ten',
#  622: 'e',
#  623: 'measured',
#  624: 'quiet',
#  625: 'knock',
#  626: 'pay',
#  627: 'monday',
#  628: 'soon',
#  629: 'king',
#  630: 'pam',
#  631: 'dirty',
#  632: 'polythene',
#  633: "majesty's",
#  634: 'nice',
#  635: 'realized',
#  636: 'raccoon',
#  637: 'even',
#  638: 'looks',
#  639: 'mother',
#  640: 'mary',
#  641: 'agree',
#  642: 'shines',
#  643: 'sound',
#  644: 'cup',
#  645: 'joy',
#  646: 'which',
#  647: 'million',
#  648: 'call',
#  649: 'sounds',
#  650: 'skin',
#  651: 'cool',
#  652: 'remain',
#  653: 'moments',
#  654: 'recall',
#  655: 'compares',
#  656: 'memories',
#  657: 'meaning',
#  658: 'wings',
#  659: 'cold',
#  660: 'awake',
#  661: 'pillow',
#  662: 'invitations',
#  663: 'celebrations',
#  664: 'saved',
#  665: 'works',
#  666: 'matter',
#  667: 'tune',
#  668: 'singer',
#  669: 'bra',
#  670: 'twenty',
#  671: 'begins',
#  672: 'kids',
#  673: 'yard',
#  674: 'jones',
#  675: 'market',
#  676: 'lets',
#  677: 'stays',
#  678: 'losing',
#  679: 'valentine',
#  680: 'greetings',
#  681: 'bottle',
#  682: 'quarter',
#  683: 'lock',
#  684: 'word',
#  685: 'handy',
#  686: 'mending',
#  687: 'fuse',
#  688: 'knit',
#  689: 'sweater',
#  690: 'fireside',
#  691: 'ride',
#  692: 'digging',
#  693: 'weeds',
#  694: 'cottage',
#  695: 'isle',
#  696: 'wight',
#  697: 'shall',
#  698: 'scrimp',
#  699: 'grandchildren',
#  700: 'vera',
#  701: 'chuck',
#  702: 'dave',
#  703: 'postcard',
#  704: 'line',
#  705: 'stating',
#  706: 'precisely',
#  707: 'sincerely',
#  708: 'wasting',
#  709: 'form',
#  710: "feelin'",
#  711: 'past',
#  712: 'needed',
#  713: "anybody's",
#  714: 'self',
#  715: 'assured',
#  716: 'doors',
#  717: 'ways',
#  718: 'somewhere',
#  719: 'style',
#  720: 'flat',
#  721: 'joo',
#  722: 'roller',
#  723: 'joker',
#  724: 'finger',
#  725: 'shoot',
#  726: 'early',
#  727: 'birds',
#  728: 'roses',
#  729: 'fragrant',
#  730: 'meadows',
#  731: 'dawn',
#  732: 'dew',
#  733: 'count',
#  734: 'brother',
#  735: 'wait',
#  736: 'town',
#  737: 'sailed',
#  738: 'next',
#  739: 'cut',
#  740: 'cable',
#  741: 'aye',
#  742: 'captain',
#  743: 'whenever',
#  744: 'air',
#  745: 'endear',
#  746: 'worry',
#  747: 'own',
#  748: 'sight',
#  749: 'pigs',
#  750: 'gun',
#  751: 'stupid',
#  752: 'naughty',
#  753: 'eye',
#  754: 'set',
#  755: 'turning',
#  756: 'rather',
#  757: 'car',
#  758: 'crowd',
#  759: 'book',
#  760: 'noticed',
#  761: 'late',
#  762: 'thousand',
#  763: 'pleasure',
#  764: 'corner',
#  765: 'pouring',
#  766: 'strange',
#  767: 'fireman',
#  768: 'queen',
#  769: 'fire',
#  770: 'clean',
#  771: 'pies',
#  772: 'shaves',
#  773: 'loretta',
#  774: 'woman',
#  775: 'coming',
#  776: 'gets',
#  777: 'turns',
#  778: 'picture',
#  779: 'quite',
#  780: 'kaleidoscope',
#  781: 'flowers',
#  782: 'rocking',
#  783: 'eat',
#  784: 'appear',
#  785: 'clouds',
#  786: 'school',
#  787: 'chair',
#  788: 'puts',
#  789: 'teacher',
#  790: 'ready',
#  791: "junior's",
#  792: 'shop',
#  793: 'bath',
#  794: 'brings',
#  795: 'bright',
#  796: 'stars',
#  797: 'bye',
#  798: 'wow',
#  799: 'norwegian',
#  800: 'wood',
#  801: 'worked',
#  802: 'closer',
#  803: 'yi',
#  804: 'yay',
#  805: 'thinking',
#  806: 'pride',
#  807: 'eleanor',
#  808: 'rigby',
#  809: 'church',
#  810: 'waits',
#  811: 'window',
#  812: 'wearing',
#  813: 'mckenzie',
#  814: 'along',
#  815: 'boom',
#  816: 'crossed',
#  817: 'danced',
#  818: 'close',
#  819: 'miss',
#  820: 'lips',
#  821: 'log',
#  822: 'moan',
#  823: 'owww',
#  824: 'special',
#  825: 'sunny',
#  826: 'lie',
#  827: 'satisfied',
#  828: 'introduce',
#  829: 'might',
#  830: 'beside',
#  831: 'share',
#  832: 'believing',
#  833: 'dies',
#  834: 'watching',
#  835: 'forget',
#  836: "di'n'di",
#  837: 'bup',
#  838: 'dreamer',
#  839: 'join',
#  840: 'leads',
#  841: 'enough',
#  842: 'did',
#  843: 'warm',
#  844: 'lies',
#  845: 'safe',
#  846: 'c',
#  847: 'sail',
#  848: 'ship',
#  849: 'chop',
#  850: 'skip',
#  851: 'rope',
#  852: 'celebrate',
#  853: 'penetrate',
#  854: 'pick',
#  855: 'radiate',
#  856: 'imitate',
#  857: 'lorry',
#  858: 'syndicate',
#  859: "haven't",
#  860: 'putting',
#  861: 'joke',
#  862: 'brain',
#  863: 'weeks',
#  864: 'insane',
#  865: 'park',
#  866: 'roof',
#  867: 'bag',
#  868: 'ukraine',
#  869: 'west',
#  870: 'moscow',
#  871: "georgia's",
#  872: 'hu',
#  873: 'mountain',
#  874: 'grin',
#  875: 'perfectly',
#  876: 'talking',
#  877: 'magic',
#  878: 'na',
#  879: "everybody's",
#  880: 'mi',
#  881: 'amore',
#  882: 'sleeps',
#  883: 'dressed',
#  884: "sunday's",
#  885: "tuesday's",
#  886: 'wall',
#  887: 'greet',
#  888: 'brand',
#  889: 'beautiful',
#  890: 'open',
#  891: 'happen',
#  892: 'bit',
#  893: 'command',
#  894: 'himself',
#  895: 'checked',
#  896: "gideon's",
#  897: 'bible',
#  898: 'rival',
#  899: 'called',
#  900: 'doc',
#  901: 'saying',
#  902: 'short',
#  903: 'fussing',
#  904: 'fighting',
#  905: 'crime',
#  906: 'oa',
#  907: 'troubles',
#  908: 'seemed',
#  909: 'far',
#  910: 'half',
#  911: 'used',
#  912: 'shadow',
#  913: 'hanging',
#  914: 'trouble',
#  915: 'hour',
#  916: 'darkness',
#  917: 'front',
#  918: 'hearted',
#  919: 'parted',
#  920: 'cloudy',
#  921: 'wake',
#  922: 'flowing',
#  923: 'endless',
#  924: 'slither',
#  925: 'wildly',
#  926: 'slip',
#  927: 'pools',
#  928: 'sorrow',
#  929: 'drifting',
#  930: 'possessing',
#  931: 'caressing',
#  932: 'images',
#  933: 'thoughts',
#  934: 'meander',
#  935: 'restless',
#  936: 'letter',
#  937: 'box',
#  938: 'tumble',
#  939: 'blindly',
#  940: 'laughter',
#  941: 'shades',
#  942: 'inciting',
#  943: 'inviting',
#  944: 'limitless',
#  945: 'undying',
#  946: 'suns',
#  947: 'afraid',
#  948: 'minute',
#  949: 'anytime',
#  950: 'refrain',
#  951: 'shoulders',
#  952: 'colder',
#  953: 'perform',
#  954: 'movement',
#  955: 'shoulder',
#  956: 'sunken',
#  957: 'winter',
#  958: 'returning',
#  959: 'faces',
#  960: 'ice',
#  961: 'melting',
#  962: 'clear',
#  963: 'sung',
#  964: 'shown',
#  965: 'meant',
#  966: "mem'ries",
#  967: 'closed',
#  968: 'misunderstanding',
#  969: 'sometimes',
#  970: 'disagree',
#  971: 'barrow',
#  972: 'marketplace',
#  973: 'trolley',
#  974: "jeweler's",
#  975: 'store',
#  976: 'buys',
#  977: 'carat',
#  978: 'sings',
#  979: 'fun',
#  980: 'bla',
#  981: "'til",
#  982: 'mornings',
#  983: 'yours',
#  984: 'lasts',
#  985: 'independence',
#  986: 'vanish',
#  987: 'haze',
#  988: 'insecure',
#  989: 'moves',
#  990: 'attracts',
#  991: 'woos',
#  992: 'asking',
#  993: 'stick',
#  994: 'top',
#  995: "groovin'",
#  996: 'eyeballs',
#  997: 'holy',
#  998: 'wear',
#  999: 'shoeshine',
#  1000: 'toe',
#  ...}

# %%
# Cantidad de palabras en el vocabulario
vocab_size = len(tok.word_counts)
vocab_size
# Out:
# 1628

# %%
# ¡Ojo! y_data_int comienza en "1" en vez de "0"
# valor minimo:
min(y_data_int)
# Out:
# 1

# %%
# Hay que restar 1
y_data_int_offset = y_data_int - 1
min(y_data_int_offset)
# Out:
# 0

# %%
class Data(Dataset):
    def __init__(self, x, y):
        # Convertir los arrays de numpy a tensores. 
        # pytorch espera en general entradas 32bits
        self.x = torch.from_numpy(x.astype(np.int32))
        # Transformar los datos a oneHotEncoding
        # la loss function esperan la salida float
        self.y = F.one_hot(torch.from_numpy(y), num_classes=vocab_size).float()

        self.len = self.y.shape[0]

    def __getitem__(self,index):
        return self.x[index], self.y[index]

    def __len__(self):
        return self.len

data_set = Data(x_data, y_data_int_offset)

input_size = data_set.x.shape[1]
print("input_size:", input_size)

output_dim = data_set.y.shape[1]
print("Output dim", output_dim)
# Out:
# input_size: 3
# Output dim 1628

# %%
torch.manual_seed(42)
valid_set_size = int(data_set.len * 0.2)
train_set_size = data_set.len - valid_set_size

train_set = torch.utils.data.Subset(data_set, range(train_set_size))
valid_set = torch.utils.data.Subset(data_set, range(train_set_size, data_set.len))

print("Tamaño del conjunto de entrenamiento:", len(train_set))
print("Tamaño del conjunto de validacion:", len(valid_set))

train_batch_size = 32
train_loader = torch.utils.data.DataLoader(train_set, batch_size=train_batch_size, shuffle=True)
valid_loader = torch.utils.data.DataLoader(valid_set, batch_size=len(valid_set), shuffle=False)
# Out:
# Tamaño del conjunto de entrenamiento: 11507
# Tamaño del conjunto de validacion: 2876

# %% [markdown]
# ### 4 - Entrenar el modelo

# %%
class Model1(nn.Module):
    def __init__(self, vocab_size, output_dim):
        super().__init__()
        # num_embeddings = vocab_size --> 1628 palabras distintas + 1 para padding o UNK
        # embedding_dim = 5 --> crear embeddings de tamaño 5 (tamaño variable y ajustable)
        self.lstm_size = 64
        self.num_layers = 2
        self.embedding = nn.Embedding(num_embeddings=vocab_size+1, embedding_dim=5, padding_idx=0)
        self.lstm1 = nn.LSTM(input_size=5, hidden_size=self.lstm_size, batch_first=True,
                            num_layers=self.num_layers, dropout=0.2) # LSTM layer
        self.fc1 = nn.Linear(in_features=self.lstm_size, out_features=32) # Fully connected layer
        self.fc2 = nn.Linear(in_features=32, out_features=output_dim) # Fully connected layer
        
        self.relu = nn.ReLU()
        self.softmax = nn.Softmax(dim=1) # normalize in dim 1

    def forward(self, x, prev_state=None):
        if prev_state is None:
            # En cada nueva inferencia reinicio el hidden state
            # de la LSTM al menos que sea pasado por parámetro el
            # elstado de previo
            # Esta acción se realiza especialmente para que
            # el hidden_state de la última inferencia no afecte
            # a la siguiente
            batch_size = x.shape[0] #(batch, seq_size)
            prev_state = self.init_hidden(batch_size)

        out = self.embedding(x)
        lstm_output, (ht, ct) = self.lstm1(out, prev_state)
        out = self.relu(self.fc1(lstm_output[:,-1,:])) # take last output (last seq)
        out = self.softmax(self.fc2(out))
        return out

    def init_hidden(self, batch_size):
        return (torch.zeros(self.num_layers, batch_size, self.lstm_size),
                torch.zeros(self.num_layers, batch_size, self.lstm_size))

model1 = Model1(vocab_size=vocab_size, output_dim=output_dim)

# Crear el optimizador la una función de error
model1_optimizer = torch.optim.Adam(model1.parameters(), lr=0.001)
model1_criterion = torch.nn.CrossEntropyLoss()  # Para clasificación multi categórica

# Por defecto torchinfo testea el modelo con torch.FloatTensor
summary(model1, input_size=(1, input_size), dtypes=['torch.IntTensor'], device=torch.device('cpu'))

# otra posibilidad
#summary(model1, input_data=data_set[0][0].unsqueeze(0))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# Model1                                   [1, 1628]                 --
# ├─Embedding: 1-1                         [1, 3, 5]                 8,145
# ├─LSTM: 1-2                              [1, 3, 64]                51,456
# ├─Linear: 1-3                            [1, 32]                   2,080
# ├─ReLU: 1-4                              [1, 32]                   --
# ├─Linear: 1-5                            [1, 1628]                 53,724
# ├─Softmax: 1-6                           [1, 1628]                 --
# ==========================================================================================
# Total params: 115,405
# Trainable params: 115,405
# Non-trainable params: 0
# Total mult-adds (M): 0.22
# ==========================================================================================
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.01
# Params size (MB): 0.46
# Estimated Total Size (MB): 0.48
# ==========================================================================================

# %%
history1 = train(model1,
                train_loader,
                valid_loader,
                model1_optimizer,
                model1_criterion,
                epochs=100
                )
# Out:
# Epoch: 1/100 - Train loss 7.356 - Train accuracy 0.045 - Valid Loss 7.356 - Valid accuracy 0.040
# Epoch: 2/100 - Train loss 7.346 - Train accuracy 0.050 - Valid Loss 7.356 - Valid accuracy 0.040
# Epoch: 3/100 - Train loss 7.346 - Train accuracy 0.050 - Valid Loss 7.356 - Valid accuracy 0.040
# Epoch: 4/100 - Train loss 7.346 - Train accuracy 0.050 - Valid Loss 7.356 - Valid accuracy 0.040
# Epoch: 5/100 - Train loss 7.346 - Train accuracy 0.050 - Valid Loss 7.356 - Valid accuracy 0.040
# Epoch: 6/100 - Train loss 7.346 - Train accuracy 0.050 - Valid Loss 7.356 - Valid accuracy 0.040
# Epoch: 7/100 - Train loss 7.346 - Train accuracy 0.050 - Valid Loss 7.356 - Valid accuracy 0.040
# Epoch: 8/100 - Train loss 7.345 - Train accuracy 0.051 - Valid Loss 7.356 - Valid accuracy 0.040
# Epoch: 9/100 - Train loss 7.345 - Train accuracy 0.051 - Valid Loss 7.356 - Valid accuracy 0.040
# Epoch: 10/100 - Train loss 7.345 - Train accuracy 0.051 - Valid Loss 7.358 - Valid accuracy 0.038
# Epoch: 11/100 - Train loss 7.345 - Train accuracy 0.051 - Valid Loss 7.356 - Valid accuracy 0.040
# Epoch: 12/100 - Train loss 7.344 - Train accuracy 0.052 - Valid Loss 7.356 - Valid accuracy 0.040
# Epoch: 13/100 - Train loss 7.344 - Train accuracy 0.052 - Valid Loss 7.355 - Valid accuracy 0.042
# Epoch: 14/100 - Train loss 7.344 - Train accuracy 0.052 - Valid Loss 7.355 - Valid accuracy 0.041
# Epoch: 15/100 - Train loss 7.342 - Train accuracy 0.054 - Valid Loss 7.353 - Valid accuracy 0.043
# Epoch: 16/100 - Train loss 7.341 - Train accuracy 0.055 - Valid Loss 7.355 - Valid accuracy 0.042
# Epoch: 17/100 - Train loss 7.341 - Train accuracy 0.055 - Valid Loss 7.356 - Valid accuracy 0.040
# Epoch: 18/100 - Train loss 7.341 - Train accuracy 0.055 - Valid Loss 7.355 - Valid accuracy 0.041
# Epoch: 19/100 - Train loss 7.341 - Train accuracy 0.056 - Valid Loss 7.353 - Valid accuracy 0.043
# Epoch: 20/100 - Train loss 7.340 - Train accuracy 0.056 - Valid Loss 7.354 - Valid accuracy 0.041
# Epoch: 21/100 - Train loss 7.340 - Train accuracy 0.056 - Valid Loss 7.353 - Valid accuracy 0.043
# Epoch: 22/100 - Train loss 7.338 - Train accuracy 0.058 - Valid Loss 7.352 - Valid accuracy 0.045
# Epoch: 23/100 - Train loss 7.336 - Train accuracy 0.061 - Valid Loss 7.350 - Valid accuracy 0.046
# Epoch: 24/100 - Train loss 7.334 - Train accuracy 0.062 - Valid Loss 7.351 - Valid accuracy 0.045
# Epoch: 25/100 - Train loss 7.333 - Train accuracy 0.063 - Valid Loss 7.351 - Valid accuracy 0.045
# Epoch: 26/100 - Train loss 7.333 - Train accuracy 0.063 - Valid Loss 7.343 - Valid accuracy 0.055
# Epoch: 27/100 - Train loss 7.331 - Train accuracy 0.065 - Valid Loss 7.349 - Valid accuracy 0.047
# Epoch: 28/100 - Train loss 7.330 - Train accuracy 0.066 - Valid Loss 7.347 - Valid accuracy 0.049
# Epoch: 29/100 - Train loss 7.330 - Train accuracy 0.066 - Valid Loss 7.345 - Valid accuracy 0.052
# Epoch: 30/100 - Train loss 7.328 - Train accuracy 0.068 - Valid Loss 7.347 - Valid accuracy 0.050
# Epoch: 31/100 - Train loss 7.327 - Train accuracy 0.069 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 32/100 - Train loss 7.326 - Train accuracy 0.070 - Valid Loss 7.345 - Valid accuracy 0.051
# Epoch: 33/100 - Train loss 7.326 - Train accuracy 0.070 - Valid Loss 7.346 - Valid accuracy 0.050
# Epoch: 34/100 - Train loss 7.326 - Train accuracy 0.071 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 35/100 - Train loss 7.326 - Train accuracy 0.071 - Valid Loss 7.345 - Valid accuracy 0.052
# Epoch: 36/100 - Train loss 7.325 - Train accuracy 0.071 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 37/100 - Train loss 7.325 - Train accuracy 0.071 - Valid Loss 7.345 - Valid accuracy 0.051
# Epoch: 38/100 - Train loss 7.325 - Train accuracy 0.072 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 39/100 - Train loss 7.324 - Train accuracy 0.072 - Valid Loss 7.349 - Valid accuracy 0.047
# Epoch: 40/100 - Train loss 7.322 - Train accuracy 0.074 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 41/100 - Train loss 7.324 - Train accuracy 0.072 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 42/100 - Train loss 7.323 - Train accuracy 0.074 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 43/100 - Train loss 7.320 - Train accuracy 0.076 - Valid Loss 7.349 - Valid accuracy 0.048
# Epoch: 44/100 - Train loss 7.320 - Train accuracy 0.076 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 45/100 - Train loss 7.320 - Train accuracy 0.076 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 46/100 - Train loss 7.319 - Train accuracy 0.077 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 47/100 - Train loss 7.319 - Train accuracy 0.077 - Valid Loss 7.347 - Valid accuracy 0.050
# Epoch: 48/100 - Train loss 7.318 - Train accuracy 0.078 - Valid Loss 7.350 - Valid accuracy 0.046
# Epoch: 49/100 - Train loss 7.319 - Train accuracy 0.077 - Valid Loss 7.346 - Valid accuracy 0.050
# Epoch: 50/100 - Train loss 7.318 - Train accuracy 0.078 - Valid Loss 7.347 - Valid accuracy 0.049
# Epoch: 51/100 - Train loss 7.317 - Train accuracy 0.080 - Valid Loss 7.348 - Valid accuracy 0.049
# Epoch: 52/100 - Train loss 7.316 - Train accuracy 0.080 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 53/100 - Train loss 7.316 - Train accuracy 0.080 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 54/100 - Train loss 7.315 - Train accuracy 0.081 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 55/100 - Train loss 7.313 - Train accuracy 0.083 - Valid Loss 7.349 - Valid accuracy 0.047
# Epoch: 56/100 - Train loss 7.313 - Train accuracy 0.083 - Valid Loss 7.349 - Valid accuracy 0.047
# Epoch: 57/100 - Train loss 7.313 - Train accuracy 0.084 - Valid Loss 7.347 - Valid accuracy 0.050
# Epoch: 58/100 - Train loss 7.312 - Train accuracy 0.085 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 59/100 - Train loss 7.312 - Train accuracy 0.085 - Valid Loss 7.351 - Valid accuracy 0.045
# Epoch: 60/100 - Train loss 7.313 - Train accuracy 0.083 - Valid Loss 7.350 - Valid accuracy 0.046
# Epoch: 61/100 - Train loss 7.312 - Train accuracy 0.085 - Valid Loss 7.346 - Valid accuracy 0.050
# Epoch: 62/100 - Train loss 7.312 - Train accuracy 0.084 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 63/100 - Train loss 7.310 - Train accuracy 0.086 - Valid Loss 7.349 - Valid accuracy 0.047
# Epoch: 64/100 - Train loss 7.311 - Train accuracy 0.086 - Valid Loss 7.349 - Valid accuracy 0.048
# Epoch: 65/100 - Train loss 7.310 - Train accuracy 0.086 - Valid Loss 7.349 - Valid accuracy 0.047
# Epoch: 66/100 - Train loss 7.310 - Train accuracy 0.086 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 67/100 - Train loss 7.309 - Train accuracy 0.087 - Valid Loss 7.349 - Valid accuracy 0.047
# Epoch: 68/100 - Train loss 7.308 - Train accuracy 0.088 - Valid Loss 7.350 - Valid accuracy 0.047
# Epoch: 69/100 - Train loss 7.308 - Train accuracy 0.088 - Valid Loss 7.349 - Valid accuracy 0.047
# Epoch: 70/100 - Train loss 7.308 - Train accuracy 0.088 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 71/100 - Train loss 7.309 - Train accuracy 0.088 - Valid Loss 7.349 - Valid accuracy 0.048
# Epoch: 72/100 - Train loss 7.308 - Train accuracy 0.088 - Valid Loss 7.350 - Valid accuracy 0.047
# Epoch: 73/100 - Train loss 7.308 - Train accuracy 0.089 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 74/100 - Train loss 7.308 - Train accuracy 0.088 - Valid Loss 7.348 - Valid accuracy 0.049
# Epoch: 75/100 - Train loss 7.308 - Train accuracy 0.089 - Valid Loss 7.350 - Valid accuracy 0.046
# Epoch: 76/100 - Train loss 7.307 - Train accuracy 0.089 - Valid Loss 7.349 - Valid accuracy 0.048
# Epoch: 77/100 - Train loss 7.308 - Train accuracy 0.089 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 78/100 - Train loss 7.306 - Train accuracy 0.090 - Valid Loss 7.347 - Valid accuracy 0.049
# Epoch: 79/100 - Train loss 7.307 - Train accuracy 0.090 - Valid Loss 7.350 - Valid accuracy 0.046
# Epoch: 80/100 - Train loss 7.307 - Train accuracy 0.089 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 81/100 - Train loss 7.306 - Train accuracy 0.090 - Valid Loss 7.349 - Valid accuracy 0.047
# Epoch: 82/100 - Train loss 7.306 - Train accuracy 0.090 - Valid Loss 7.350 - Valid accuracy 0.046
# Epoch: 83/100 - Train loss 7.306 - Train accuracy 0.090 - Valid Loss 7.349 - Valid accuracy 0.048
# Epoch: 84/100 - Train loss 7.307 - Train accuracy 0.089 - Valid Loss 7.349 - Valid accuracy 0.047
# Epoch: 85/100 - Train loss 7.306 - Train accuracy 0.090 - Valid Loss 7.350 - Valid accuracy 0.046
# Epoch: 86/100 - Train loss 7.306 - Train accuracy 0.090 - Valid Loss 7.350 - Valid accuracy 0.047
# Epoch: 87/100 - Train loss 7.306 - Train accuracy 0.090 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 88/100 - Train loss 7.307 - Train accuracy 0.089 - Valid Loss 7.349 - Valid accuracy 0.048
# Epoch: 89/100 - Train loss 7.306 - Train accuracy 0.090 - Valid Loss 7.350 - Valid accuracy 0.047
# Epoch: 90/100 - Train loss 7.306 - Train accuracy 0.090 - Valid Loss 7.349 - Valid accuracy 0.047
# Epoch: 91/100 - Train loss 7.307 - Train accuracy 0.090 - Valid Loss 7.348 - Valid accuracy 0.048
# Epoch: 92/100 - Train loss 7.306 - Train accuracy 0.090 - Valid Loss 7.349 - Valid accuracy 0.047
# Epoch: 93/100 - Train loss 7.306 - Train accuracy 0.091 - Valid Loss 7.349 - Valid accuracy 0.047
# Epoch: 94/100 - Train loss 7.306 - Train accuracy 0.091 - Valid Loss 7.350 - Valid accuracy 0.046
# Epoch: 95/100 - Train loss 7.305 - Train accuracy 0.091 - Valid Loss 7.351 - Valid accuracy 0.046
# Epoch: 96/100 - Train loss 7.305 - Train accuracy 0.091 - Valid Loss 7.350 - Valid accuracy 0.046
# Epoch: 97/100 - Train loss 7.305 - Train accuracy 0.091 - Valid Loss 7.351 - Valid accuracy 0.045
# Epoch: 98/100 - Train loss 7.305 - Train accuracy 0.091 - Valid Loss 7.350 - Valid accuracy 0.047
# Epoch: 99/100 - Train loss 7.306 - Train accuracy 0.090 - Valid Loss 7.353 - Valid accuracy 0.043
# Epoch: 100/100 - Train loss 7.305 - Train accuracy 0.091 - Valid Loss 7.351 - Valid accuracy 0.046

# %%
epoch_count = range(1, len(history1['accuracy']) + 1)
sns.lineplot(x=epoch_count,  y=history1['accuracy'], label='train')
sns.lineplot(x=epoch_count,  y=history1['val_accuracy'], label='valid')
plt.show()

# %% [markdown]
# __Es importante__ destacar que en este ejemplo estamos entrenando nuestro propios Embeddings y para ello se requiere mucha data. En los ejemplos que realizaremos de aquí en más utilizaremos más datos, embeddings pre-enternados o modelos pre-entrenados.

# %% [markdown]
# ### 5 - Predicción de próxima palabra

# %%
# pad_sequences
# Si la secuencia de entrada supera al input_seq_len (3) se trunca
# Si la secuencia es más corta se agregna ceros al comienzo

# %%
# Se utilizará gradio para ensayar el modelo
# Herramienta poderosa para crear interfaces rápidas para ensayar modelos
# https://gradio.app/
import sys
# !{sys.executable} -m pip install gradio --quiet
# Out:
#      |████████████████████████████████| 5.1 MB 5.2 MB/s
#      |████████████████████████████████| 253 kB 74.6 MB/s
#      |████████████████████████████████| 2.0 MB 56.1 MB/s
#      |████████████████████████████████| 212 kB 61.7 MB/s
#      |████████████████████████████████| 53 kB 2.6 MB/s
#      |████████████████████████████████| 54 kB 3.7 MB/s
#      |████████████████████████████████| 1.1 MB 53.9 MB/s
#      |████████████████████████████████| 84 kB 4.1 MB/s
#      |████████████████████████████████| 144 kB 72.7 MB/s
#      |████████████████████████████████| 271 kB 64.7 MB/s
#      |████████████████████████████████| 94 kB 4.3 MB/s
#      |████████████████████████████████| 11.1 MB 58.7 MB/s
#      |████████████████████████████████| 63 kB 2.4 MB/s
#      |████████████████████████████████| 80 kB 11.8 MB/s
#      |████████████████████████████████| 43 kB 2.8 MB/s
#      |████████████████████████████████| 856 kB 68.0 MB/s
#      |████████████████████████████████| 4.0 MB 50.0 MB/s
#      |████████████████████████████████| 62 kB 1.1 MB/s
#      |████████████████████████████████| 58 kB 6.7 MB/s
#   Building wheel for ffmpy (setup.py) ... done
#   Building wheel for python-multipart (setup.py) ... done

# %%
import gradio as gr

def model_response(human_text):

    # Encodeamos
    encoded = tok.texts_to_sequences([human_text])[0]
    # Si tienen distinto largo
    encoded = pad_sequences([encoded], maxlen=3, padding='pre')
    
    # Transformo a tensor
    tensor = torch.from_numpy(encoded.astype(np.int32))

    # Predicción softmax
    y_hat = model1(tensor).argmax(axis=-1)

    # Debemos buscar en el vocabulario la palabra
    # que corresopnde al indice (y_hat) predicho por le modelo
    out_word = ''
    for word, index in tok.word_index.items():
        if index == y_hat:
            out_word = word
            break

    # Agrego la palabra a la frase predicha
    return human_text + ' ' + out_word

iface = gr.Interface(
    fn=model_response,
    inputs=["textbox"],
    outputs="text",
    layout="vertical")

iface.launch(debug=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/gradio/deprecation.py:40: UserWarning: `layout` parameter is deprecated, and it has no effect
#   warnings.warn(value)
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://17280.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
#         <iframe
#             width="900"
#             height="500"
#             src="https://17280.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
# Keyboard interruption in main thread... closing server.
# (<gradio.routes.App at 0x7f68dd6cfe50>,
#  'http://127.0.0.1:7860/',
#  'https://17280.gradio.app')

# %% [markdown]
# ### 6 - Generación de secuencias nuevas

# %%
def generate_seq(model, tokenizer, seed_text, max_length, n_words):
    """
        Exec model sequence prediction

        Args:
            model (keras): modelo entrenado
            tokenizer (keras tokenizer): tonenizer utilizado en el preprocesamiento
            seed_text (string): texto de entrada (input_seq)
            max_length (int): máxima longitud de la sequencia de entrada
            n_words (int): números de palabras a agregar a la sequencia de entrada
        returns:
            output_text (string): sentencia con las "n_words" agregadas
    """
    output_text = seed_text
	# generate a fixed number of words
    for _ in range(n_words):
		# Encodeamos
        encoded = tokenizer.texts_to_sequences([output_text])[0]
		# Si tienen distinto largo
        encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')
		
        # Transformo a tensor
        tensor = torch.from_numpy(encoded.astype(np.int32))

        # Predicción softmax
        y_hat = model1(tensor).argmax(axis=-1)

		# Vamos concatenando las predicciones
        out_word = ''

        # Debemos buscar en el vocabulario la palabra
        # que corresopnde al indice (y_hat) predicho por le modelo
        for word, index in tokenizer.word_index.items():
            if index == y_hat:
                out_word = word
                break

		# Agrego las palabras a la frase predicha
        output_text += ' ' + out_word
    return output_text

# %%
input_text='hey jude don\'t'

generate_seq(model1, tok, input_text, max_length=3, n_words=2)
# Out:
# "hey jude don't you "

# %% [markdown]
# ### 7 - Conclusiones
# El modelo entrenado tuvo un muy mail desempeño en el entrenamiento además de overfitting. Cuestiones que podrían mejorarse:
# - Agregar más capas o neuronaes
# - Incrementar la cantidad de épocas
# - Agregar BRNN
#
# Es importante destacar que en este ejemplo estamos entrenando nuestro propios Embeddings, y para ello se requiere mucha data. En los ejemplos que realizaremos de aquí en más utilizaremos más datos, embeddings pre-enternados o modelos pre-entrenados.
